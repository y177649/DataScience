# %% [markdown]
# データの読み込み

# %%
import pandas as pd
import numpy as np

drink = pd.read_csv('https://takafumikubota.jp/pandas/data/kakei_softdrink.csv',encoding='cp932')
drink.head()
# Out:
#   pref ntt nikkei  och2022  tea2022  cof2022  coc2022  fru2022  sod2022  \
# 0  北海道   E      O     3678      684     6112      357     7069     9048
# 1  青森県   E      O     2117      368     6245      499    10291     9412
# 2  岩手県   E      O     3652      537     4703      429     8215     9336
# 3  宮城県   E      O     3272      640     5132      394     7228     9268
# 4  秋田県   E      O     2472      536     4348      234     9393     6641
#
#    yak2022  ...  och2013  tea2013  cof2013  coc2013  fru2013  sod2013  \
# 0     4407  ...     2951      853     5023      369     7383     5476
# 1     7545  ...     3252      697     3930      450    11526     6114
# 2     4419  ...     3174      576     3615      351     8359     3952
# 3     4456  ...     5131     1171     3432      326    10019     5446
# 4     5160  ...     3462      568     4445      301     7808     4625
#
#    yak2013  lac2013  wat2013  spo2013
# 0     2307     1308     2246        0
# 1     2872     1373      840        0
# 2     2511     1424     2178        0
# 3     4534     1223     2768        0
# 4     2888     1380     1817        0
#
# [5 rows x 103 columns]

# %%
och2022 = drink['och2022']
och2022.mean()
# Out:
# 3189.7659574468084
