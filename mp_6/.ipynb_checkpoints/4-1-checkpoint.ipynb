# %%
#21

# %%
import csv
import pandas as pd
import numpy as np

# %%
SoftdrinkData="kakei_softdrink.csv"
Data=pd.read_csv(SoftdrinkData,encoding='cp932')
#print(Data)
Data.head()
# Out:
#   pref ntt nikkei  och2022  tea2022  cof2022  coc2022  fru2022  sod2022  \
# 0  北海道   E      O     3678      684     6112      357     7069     9048
# 1  青森県   E      O     2117      368     6245      499    10291     9412
# 2  岩手県   E      O     3652      537     4703      429     8215     9336
# 3  宮城県   E      O     3272      640     5132      394     7228     9268
# 4  秋田県   E      O     2472      536     4348      234     9393     6641
#
#    yak2022  lac2022  wat2022  spo2022  och2021  tea2021  cof2021  coc2021  \
# 0     4407     2455     3861     1407     2867      963     4843      422
# 1     7545     3137     2390     1931     1724      532     5135      321
# 2     4419     2949     3187     1759     3528      543     4385      394
# 3     4456     2643     4679     1775     4490     1897     5771      335
# 4     5160     1670     2184     1624     3953      566     3159      324
#
#    fru2021  sod2021  yak2021  lac2021  wat2021  spo2021  och2020  tea2020  \
# ...

# %%
column_list=Data.columns.tolist()
columns_list=column_list[3:]
column_list123=column_list[:3]
data2021=columns_list[9:20]
data2021[0]="pref"
print(data2021)
# Out:
# ['pref', 'och2021', 'tea2021', 'cof2021', 'coc2021', 'fru2021', 'sod2021', 'yak2021', 'lac2021', 'wat2021', 'spo2021']

# %%
Data[data2021]
# Out:
#     pref  och2021  tea2021  cof2021  coc2021  fru2021  sod2021  yak2021  \
# 0    北海道     2867      963     4843      422     7669     7764     2591
# 1    青森県     1724      532     5135      321    10091     8732     5487
# 2    岩手県     3528      543     4385      394     8849     9312     2871
# 3    宮城県     4490     1897     5771      335     7045     8795     5471
# 4    秋田県     3953      566     3159      324     8683     6313     4416
# 5    山形県     2492      492     4038      294     6885    10565     4664
# 6    福島県     4103     1104     4922      246     8659     6428     5584
# 7    茨城県     4065      981     4497      368     7143     6872     4969
# 8    栃木県     3586      908     6045      422     5896     7206     4129
# 9    群馬県     5058     1214     4924      404     7644     7624     6413
# 10   埼玉県     3446     1359     5595      549     9140    10329     5150
# 11   千葉県     5173     1062     4795      429     7634     7124     4715
# ...

# %%
Data[data2021]
# Out:
#     pref  och2021  tea2021  cof2021  coc2021  fru2021  sod2021  yak2021  \
# 0    北海道     2867      963     4843      422     7669     7764     2591
# 1    青森県     1724      532     5135      321    10091     8732     5487
# 2    岩手県     3528      543     4385      394     8849     9312     2871
# 3    宮城県     4490     1897     5771      335     7045     8795     5471
# 4    秋田県     3953      566     3159      324     8683     6313     4416
# 5    山形県     2492      492     4038      294     6885    10565     4664
# 6    福島県     4103     1104     4922      246     8659     6428     5584
# 7    茨城県     4065      981     4497      368     7143     6872     4969
# 8    栃木県     3586      908     6045      422     5896     7206     4129
# 9    群馬県     5058     1214     4924      404     7644     7624     6413
# 10   埼玉県     3446     1359     5595      549     9140    10329     5150
# 11   千葉県     5173     1062     4795      429     7634     7124     4715
# ...

# %%
# tea2021カラムで昇順にソートし、結果をtea2021カラムだけに絞る
sort_tea = Data.sort_values(by='tea2021')[['tea2021']].head()

# och2021カラムで降順にソートし、結果をoch2021カラムだけに絞る
sort_och = Data.sort_values(by='och2021', ascending=False)[['och2021']].head()
print(sort_tea,sort_och)
# Out:
# (    tea2021
#  17      433
#  40      442
#  44      454
#  15      471
#  42      481,
#      och2021
#  21     7863
#  45     5786
#  41     5484
#  11     5173
#  9      5058)
